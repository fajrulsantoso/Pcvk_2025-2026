# %% [markdown]
# <a href="https://colab.research.google.com/github/fajrulsantoso/Pcvk_2025-2026/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# baca gambar (masih BGR)
img = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg')

# tampilkan langsung (akan terlihat warna hijau kebiru-biruan)
plt.imshow(img)
plt.axis('on')   # biar ada sumbu seperti di modul
plt.show()

# %%
# Simpan img ke variabel img2
img2 = img

# Konversi channel warna dari BGR ke RGB
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # konversi BGR -> RGB

# Tampilkan gambar dengan warna yang sudah benar
plt.imshow(img3)
plt.axis('on')  # Tampilkan sumbu koordinat
plt.title('Gambar RGB Setelah Konversi')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# ------------------------------------------
# BAGIAN 1: Baca dan tampilkan grayscale (tanpa cmap='gray')
# ------------------------------------------

img_gray = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg', cv.IMREAD_GRAYSCALE)

if img_gray is None:
    print("Gambar tidak ditemukan! Periksa kembali path-nya.")
else:
    # Tampilan salah (tanpa cmap)
    plt.imshow(img_gray)
    plt.title('Grayscale tanpa cmap (Salah!)')
    plt.axis('on')
    plt.show()

# %%
# ------------------------------------------
# BAGIAN 2: Tampilkan grayscale dengan cmap='gray'
# ------------------------------------------

plt.imshow(img_gray, cmap='gray')
plt.title('Grayscale dengan cmap=gray (Benar)')
plt.axis('on')
plt.show()

# %%
# ------------------------------------------
# BAGIAN 3: Resize, Flip, Tampilkan dan Simpan
# ------------------------------------------

# Resize ke 300x300
resized_img = cv.resize(img_gray, (300, 300))

# Flipping horizontal
flipped_img = cv.flip(resized_img, 1)

# Tampilkan hasil
plt.imshow(flipped_img, cmap='gray')
plt.title('Grayscale - Resize & Flip')
plt.axis('on')
plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Baca gambar asli (BGR)
img = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg')

# Cek apakah gambar berhasil dibaca
if img is None:
    print("Gambar tidak ditemukan! Periksa kembali path-nya.")
else:
    # Resize gambar dengan ukuran panjang 512 dan lebar 1024
    img_resized = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))  # (width, height)

    # Tampilkan gambar hasil resize
    plt.imshow(img_resized)
    plt.title('Citra RGB Resize (512x1024)')
    plt.axis('on')  # Tampilkan sumbu koordinat
    plt.show()

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Baca gambar asli (BGR)
img = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg')

# Cek apakah gambar berhasil dibaca
if img is None:
    print("Gambar tidak ditemukan! Periksa kembali path-nya.")
else:
    # Flip gambar secara vertikal (flipCode=0)
    img_flipped = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

    # Simpan file hasil flip (jika ingin disimpan)
    # cv.imwrite('/content/drive/MyDrive/Pcvk/kucing_flipped.jpg', cv.cvtColor(img_flipped, cv.COLOR_RGB2BGR))

    # Tampilkan gambar dengan ukuran canvas yang lebih besar
    fig = plt.figure(figsize=(10, 10))  # ukuran canvas (10,10)
    ax = fig.add_subplot(111)
    ax.imshow(img_flipped)
    ax.axis('on')  # tampilkan sumbu koordinat
    plt.title('Citra RGB Terbalik (Flip Vertikal)')
    plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# 1. Membuat black image dengan tipe data int16 dan ukuran (512,512,3)
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

# Tampilkan gambar hitam awal (gambar 1)
plt.imshow(black_img)
plt.title('Black Image - Awal')
plt.axis('on')
plt.show()

# %%
# 2. Tambahkan persegi panjang pada koordinat pt1 dan pt2
pt1 = (384, 0)
pt2 = (510, 150)
cv.rectangle(black_img, pt1, pt2, color=(0, 255, 0), thickness=10)  # warna hijau, tebal 10

# Tampilkan gambar dengan persegi panjang (gambar 2)
plt.imshow(black_img)
plt.title('Black Image dengan Persegi Panjang')
plt.axis('on')
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Membuat black image
black_img = np.zeros(shape=(512, 512, 3), dtype=np.int16)

# Tambahkan persegi panjang hijau (pt1 dan pt2)
cv.rectangle(black_img, (384, 0), (510, 150), color=(0, 255, 0), thickness=10)  # hijau

# Tambahkan persegi panjang biru (pt1 dan pt2)
cv.rectangle(black_img, (250, 250), (300, 300), color=(0, 0, 255), thickness=10)  # biru

# Tampilkan gambar
plt.imshow(black_img)
plt.title('Black Image dengan Dua Persegi')
plt.axis('on')
plt.show()

# %%
# Tambahkan lingkaran merah dengan center (100,100) dan radius 50
cv.circle(black_img, center=(100, 100), radius=50, color=(255, 0, 0), thickness=8)  # merah

# Tampilkan gambar hasil
plt.imshow(black_img)
plt.title('Black Image dengan Dua Persegi dan Lingkaran')
plt.axis('on')
plt.show()

# %%
# Menambahkan garis diagonal putih
cv.line(black_img, pt1=(0, 0), pt2=(512, 512), color=(255, 255, 255), thickness=5)

# Tampilkan hasil
plt.imshow(black_img)
plt.title('Black Image dengan Garis Diagonal')
plt.axis('on')
plt.show()

# %%
# Menentukan font
font = cv.FONT_HERSHEY_SIMPLEX

# Menambahkan text "Hello" warna kuning di posisi (10, 500)
cv.putText(black_img, text="Hello", org=(10, 500), fontFace=font, fontScale=4, color=(255, 255, 0), thickness=2, lineType=cv.LINE_AA)

# Tampilkan hasil
plt.imshow(black_img)
plt.title('Black Image dengan Text "Hello"')
plt.axis('on')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Membuat black image dengan tipe data int32, ukuran 512x512 dengan 3 channel (RGB)
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)

# Tampilkan black_img2
plt.imshow(black_img2)
plt.title("Black Image dengan dtype=int32")
plt.axis('on')
plt.show()

# Inisialisasi array vertices dengan tipe data int32
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)
print(vertices)

# Reshape vertices agar memiliki bentuk (4, 1, 2)
pts = vertices.reshape((-1, 1, 2))
print(pts)
# Out:
# [[100 300]
#  [200 200]
#  [400 300]
#  [200 400]]
# [[[100 300]]
#
#  [[200 200]]
#
#  [[400 300]]
#
#  [[200 400]]]

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# Membuat black image dengan tipe data int32, ukuran 512x512 dengan 3 channel (RGB)
black_img2 = np.zeros(shape=(512, 512, 3), dtype=np.int32)

# Inisialisasi array vertices dengan tipe data int32
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype=np.int32)

# Reshape vertices agar memiliki bentuk (4, 1, 2)
pts = vertices.reshape((-1, 1, 2))

# Menambahkan polyline pada black image
cv.polylines(black_img2, [pts], isClosed=True, color=(255, 0, 0), thickness=5)

# Tampilkan hasilnya
plt.imshow(black_img2)
plt.title("Black Image dengan Polyline Merah")
plt.axis('on')
plt.show()

# %% [markdown]
# **Perbedaan menampilkan gambar tanpa dan dengan matplotlib**
#
# cv.imshow() buka jendela terpisah, warna pakai format BGR (biru-merah terbalik).
# matplotlib tampilkan gambar di notebook, pakai format RGB, sehingga warna lebih benar dan bisa atur colormap.
#
# **Perbedaan tipe data int16 dan int32 pada black image**
# int16: 16-bit, nilai antara -32,768 sampai 32,767, kurang umum untuk
# gambar.
# int32: 32-bit, rentang lebih besar, cocok untuk proses citra dengan nilai besar.
# Pengaruh: tipe data menentukan rentang nilai pixel, tapi selama nilai sesuai, tampilan gambar di matplotlib sama saja.
# Fungsi cv2_imshow di Google Colab
# Gantikan cv.imshow() karena Colab tidak bisa buka jendela GUI.
# cv2_imshow() langsung tampilkan gambar di output notebook Colab.

# %% [markdown]
# **Fungsi cv2_imshow di Google Colab**
#
# Gantikan cv.imshow() karena Colab tidak bisa buka jendela GUI.
#
# cv2_imshow() langsung tampilkan gambar di output notebook Colab.

# %% [markdown]
# # TUGAS PRAKTIKUM D3

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Baca gambar asli (BGR)
img = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg')

# 1. Perhatikan ukuran gambar pixelnya
print("Ukuran gambar asli:", img.shape)

# 2. Tampilkan image channel Red-Blue dan Green-Blue saja
red_blue = img.copy()
red_blue[:, :, 1] = 0  # hilangkan channel Green
green_blue = img.copy()
green_blue[:, :, 0] = 0  # hilangkan channel Red
green_blue[:, :, 2] = 0  # hilangkan channel Red

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.title('Red-Blue Channel')
plt.imshow(cv.cvtColor(red_blue, cv.COLOR_BGR2RGB))
plt.subplot(1, 2, 2)
plt.title('Green-Blue Channel')
plt.imshow(cv.cvtColor(green_blue, cv.COLOR_BGR2RGB))
plt.show()

# 3. Tampilkan image baris ke 20-115, kolom 25-120
crop1 = img[20:116, 25:121]
plt.imshow(cv.cvtColor(crop1, cv.COLOR_BGR2RGB))
plt.title('Crop baris 20-115, kolom 25-120')
plt.show()

# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja
red_only = np.zeros_like(img)
red_only[5:31, :, 2] = img[5:31, :, 2]
plt.imshow(cv.cvtColor(red_only, cv.COLOR_BGR2RGB))
plt.title('Baris 5-30, channel Red')
plt.show()

# 5. Buat 5 kotak dengan ukuran dan warna acak pada image hitam
black_img = np.zeros_like(img)
for _ in range(5):
    x, y = np.random.randint(0, black_img.shape[1] - 50), np.random.randint(0, black_img.shape[0] - 50)
    w, h = np.random.randint(20, 50), np.random.randint(20, 50)
    color = tuple(np.random.randint(0, 256, 3).tolist())
    cv.rectangle(black_img, (x, y), (x + w, y + h), color, -1)

plt.imshow(cv.cvtColor(black_img, cv.COLOR_BGR2RGB))
plt.title('5 Kotak acak')
plt.show()

# 6. Tampilkan gambar dengan posisi terbalik (flip vertical)
img_flip = cv.flip(img, 0)  # flip vertical
plt.imshow(cv.cvtColor(img_flip, cv.COLOR_BGR2RGB))
plt.title('Gambar terbalik')
plt.show()
# Out:
# Ukuran gambar asli: (611, 612, 3)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Baca gambar asli (BGR)
img = cv.imread('/content/drive/MyDrive/Pcvk/kucing.jpg')

# Bagian 3: Membuat gambar dengan bentuk-bentuk dasar dan teks

# Buat gambar hitam kosong
black_img = np.zeros_like(img)

# 1. Gambar persegi (rectangle)
cv.rectangle(black_img, (50, 50), (150, 150), (0, 255, 0), 3)  # hijau, tebal 3

# 2. Gambar lingkaran
cv.circle(black_img, (250, 100), 50, (255, 0, 0), -1)  # biru, isi penuh

# 3. Gambar garis
cv.line(black_img, (0, 0), (300, 300), (0, 0, 255), 2)  # merah, tebal 2

# 4. Tambah teks
cv.putText(black_img, 'OpenCV', (50, 250), cv.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

# Tampilkan hasil gambar bentuk dan teks
plt.imshow(cv.cvtColor(black_img, cv.COLOR_BGR2RGB))
plt.title('Gambar bentuk dan teks')
plt.axis('off')
plt.show()

# Bagian 4: Manipulasi gambar lanjutan

# 1. Blur gambar asli (Gaussian Blur)
img_blur = cv.GaussianBlur(img, (7,7), 0)

# 2. Thresholding (ubah ke grayscale dulu)
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
_, img_thresh = cv.threshold(img_gray, 120, 255, cv.THRESH_BINARY)

# 3. Deteksi tepi menggunakan Canny
edges = cv.Canny(img_gray, 100, 200)

# Tampilkan hasil manipulasi
fig, axs = plt.subplots(1, 3, figsize=(15,5))
axs[0].imshow(cv.cvtColor(img_blur, cv.COLOR_BGR2RGB))
axs[0].set_title('Gaussian Blur')
axs[0].axis('off')

axs[1].imshow(img_thresh, cmap='gray')
axs[1].set_title('Threshold Binary')
axs[1].axis('off')

axs[2].imshow(edges, cmap='gray')
axs[2].set_title('Canny Edge Detection')
axs[2].axis('off')

plt.show()

# %% [markdown]
# #TUGAS PRAKTIKUM KELOMPOK

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Baca gambar dari Google Drive
img = cv.imread("/content/drive/MyDrive/Pcvk/fajrul.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Salin gambar agar tidak menimpa aslinya
img_copy = img.copy()

# =============================
# Tutup tulisan POLINEMA (pakai persegi panjang hijau)
cv.rectangle(img_copy, (448, 284), (918, 349), (0, 255, 0), -1)

# Tutup logo Polinema (pakai lingkaran merah)
cv.rectangle(img_copy, (164, 120), (261, 195), (255, 0, 0), -1)
# Bisa juga lingkaran agar beda bentuk:
# cv.circle(img_copy, (210, 160), 50, (255, 0, 0), -1)
# =============================

# Tampilkan hasil
plt.figure(figsize=(10,6))
plt.imshow(img_copy)
plt.axis("off")
plt.title("Kelompok 6: Tutup Logo dan Tulisan POLINEMA")
plt.show()
